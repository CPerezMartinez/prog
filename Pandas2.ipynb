# %% [markdown]
# <a href="https://colab.research.google.com/github/CPerezMartinez/prog/blob/prog/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12
# Out:
# ...
# Python 3.10.12
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.12 is already the newest version (3.12.7-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import pandas as pd

d = {'Pokemon':["Pikachu","Charmander","Bulbasaur","Vaporeon","Mewtwo","Lucario"],
     'Tipus': ["Elèctric","Foc","Planta","Aigua","Psíquic","Lluita"],
     'Atacs': ["Raig","Llençaflames","Dalla","Hidrobomba","Psicotall","Esfera Aural"],
     'Debilitat': ["Tipus terra","Tipus aigua","Tipus volador","Tipus elèctric","Tipus sinistre","Tipus psíquic"]}
df = pd.DataFrame(data=d)
df
# Out:
#       Pokemon     Tipus         Atacs       Debilitat
# 0     Pikachu  Elèctric          Raig     Tipus terra
# 1  Charmander       Foc  Llençaflames     Tipus aigua
# 2   Bulbasaur    Planta         Dalla   Tipus volador
# 3    Vaporeon     Aigua    Hidrobomba  Tipus elèctric
# 4      Mewtwo   Psíquic     Psicotall  Tipus sinistre
# 5     Lucario    Lluita  Esfera Aural   Tipus psíquic

# %%
pregunta_u = df.Pokemon[3]
print(pregunta_u)

pregunta_dos = df.Tipus[5]
print(pregunta_dos)

pregunta_tres = df.Atacs[1]
print(pregunta_tres)

pregunta_quatre = df.Debilitat[2]
print(pregunta_quatre)
# Out:
# Vaporeon
# Lluita
# Llençaflames
# Tipus volador

# %%
quantitat_de_dany = [60,70,70,110,130,110]
df['Quantitat de dany que fan'] = quantitat_de_dany
df
# Out:
#       Pokemon     Tipus         Atacs       Debilitat  \
# 0     Pikachu  Elèctric          Raig     Tipus terra
# 1  Charmander       Foc  Llençaflames     Tipus aigua
# 2   Bulbasaur    Planta         Dalla   Tipus volador
# 3    Vaporeon     Aigua    Hidrobomba  Tipus elèctric
# 4      Mewtwo   Psíquic     Psicotall  Tipus sinistre
# 5     Lucario    Lluita  Esfera Aural   Tipus psíquic
#
#    Quantitat de dany que fan
# 0                         60
# 1                         70
# 2                         70
# 3                        110
# 4                        130
# 5                        110
