# %% [markdown]
# <a href="https://colab.research.google.com/github/CPerezMartinez/prog/blob/prog/microbicho_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12
# Out:
# ...
# Python 3.11.11
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.12 is already the newest version (3.12.9-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
import pandas as pd

df=pd.read_csv("microbicho3 - Full 1.csv")
df
# Out:
#      segons  aula 23  pati  passadís
# 0         1       15    60        75
# 1         2       33    60       105
# 2         3       30    97        67
# 3         4       15    97       105
# 4         5       30    93        71
# ..      ...      ...   ...       ...
# 175     176       37    22        30
# 176     177       26    18        37
# 177     178       60    22        26
# 178     179       60    18        60
# 179     180       41    18        60
#
# [180 rows x 4 columns]

# %%
# @title segons vs passadís

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['segons']
  ys = series['passadís']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('segons', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('segons')
_ = plt.ylabel('passadís')

# %%
# @title segons vs pati

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['segons']
  ys = series['pati']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('segons', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('segons')
_ = plt.ylabel('pati')

# %%
# @title segons vs aula 23

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['segons']
  ys = series['aula 23']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('segons', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('segons')
_ = plt.ylabel('aula 23')

# %%
#Màxim i mínim aula a-23
max_u = df['aula 23'].max()
print("El màxim de l'aula a-23 és", max_u)
min_u = df['aula 23'].min()
print("El mínim de l'aula a-23 és", min_u)
# Out:
# El màxim de l'aula a-23 és 93
# El mínim de l'aula a-23 és 11

# %%
#Màxim i mínim pati
max_u = df['pati'].max()
print("El màxim del pati és",max_u)
min_u = df['pati'].min()
print("El mínim de pati és", min_u)
# Out:
# El màxim del pati és 168
# El mínim de pati és 11

# %%
#Màxim i mínim passadís
max_u = df['passadís'].max()
print("El màxim de passadís és",max_u)
min_u = df['passadís'].min()
print("El mínim de passadís és", min_u)
# Out:
# El màxim de passadís és 108
# El mínim de passadís és 15

# %%
#Mitjana ponderada
suma_u = df["aula 23"].sum()
promig_u = (suma_u/179) #redondear
suma_dos = df["pati"].sum()
promig_dos = (suma_dos/179)
suma_tres = df["passadís"].sum()
promig_tres = (suma_tres/179)

suma_total = (int(promig_u+promig_dos+promig_tres))
promig = (suma_total/3)
redondeig = (round(promig,2))
print("El promig és",redondeig)
# Out:
# El promig és 56.0
