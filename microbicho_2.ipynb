# %% [markdown]
# <a href="https://colab.research.google.com/github/CPerezMartinez/prog/blob/prog/microbicho_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12
# Out:
# ...
# Python 3.11.11
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.12-stdlib
# Suggested packages:
#   python3.12-venv
# The following NEW packages will be installed:
#   libpython3.12-stdlib python3.12
# 0 upgraded, 2 newly installed, 0 to remove and 19 not upgraded.
# Need to get 5,418 kB of archives.
# After this operation, 22.6 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.12-stdlib amd64 3.12.9-1+jammy1 [2,892 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.12 amd64 3.12.9-1+jammy1 [2,526 kB]
# Fetched 5,418 kB in 11s (491 kB/s)
# Selecting previously unselected package libpython3.12-stdlib:amd64.
# (Reading database ... 124926 files and directories currently installed.)
# ...

# %%
import pandas as pd

df=pd.read_csv("microbicho2 - Full 1 (3).csv")
df
# Out:
#      segons  aula a14  pasadis  gimnàs
# 0         1        33       67      45
# 1         2        45       60      37
# 2         3        75      101      75
# 3         4        41      108      48
# 4         5        37       86      30
# ..      ...       ...      ...     ...
# 175     176        48       45      48
# 176     177        71       48      30
# 177     178        33       56      56
# 178     179        33       45      60
# 179     180        37       75      67
#
# [180 rows x 4 columns]

# %%
# @title segons vs pasadis

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['segons']
  ys = series['pasadis']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('segons', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('segons')
_ = plt.ylabel('pasadis')

# %%
# @title segons vs gimnàs

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['segons']
  ys = series['gimnàs']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('segons', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('segons')
_ = plt.ylabel('gimnàs')

# %%
# @title segons vs aula a14

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['segons']
  ys = series['aula a14']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('segons', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('segons')
_ = plt.ylabel('aula a14')

# %%
#Màxim i mínim aula a-14
max_u = df['aula a14'].max()
print(max_u)
min_u = df['aula a14'].min()
print(min_u)
# Out:
# 97
# 18

# %%
#Màxim i mínim pasadís
max_u = df['pasadis'].max()
print(max_u)
min_u = df['pasadis'].min()
print(min_u)
# Out:
# 108
# 7

# %%
#Màxim i mínim gimnàs
max_u = df['gimnàs'].max()
print(max_u)
min_u = df['gimnàs'].min()
print(min_u)
# Out:
# 93
# 11

# %%
#Mitjana ponderada
suma_u = df["aula a14"].sum()
promig_u = (suma_u/179) #redondear
suma_dos = df["pasadis"].sum()
promig_dos = (suma_dos/179)
suma_tres = df["gimnàs"].sum()
promig_tres = (suma_tres/179)

suma_total = (int(promig_u+promig_dos+promig_tres))
promig = (suma_total/3)
print(round(promig,2))
# Out:
# 45.0
